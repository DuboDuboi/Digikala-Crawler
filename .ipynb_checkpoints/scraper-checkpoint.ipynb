# %%
import pandas as pd
import json
import csv

# %%
# Load the JSON data from the file
with open('Scraped/productsdetails.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

# Define the CSV file name
csv_file_name = 'Scraped/output.csv'

# Open the CSV file for writing
with open(csv_file_name, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer object
    csv_writer = csv.writer(csv_file)

    # Write the header row based on the keys of the first dictionary in the JSON data
    header = data[0].keys()
    csv_writer.writerow(header)

    # Write the data rows
    for item in data:
        csv_writer.writerow(item.values())

# %%
df = pd.read_csv('Scraped/output.csv')

# %%
df.id.unique().shape
# Out:
# (9936,)

# %%
df
# Out:
#               id                                           title_fa  \
# 0       11346304  گوشی موبایل سامسونگ مدل Galaxy A54 5G دو سیم ک...
# 1       11153044  گوشی موبایل شیائومی مدل Redmi Note 12 4G دو سی...
# 2       11578866  گوشی موبایل شیائومی مدل Poco F5 دو سیم کارت ظر...
# 3       11428316  گوشی موبایل شیائومی مدل Redmi Note 12 Pro 5G د...
# 4        7475119  گوشی موبایل سامسونگ مدل Galaxy S21 FE 5G دو سی...
# ...          ...                                                ...
# 9931   [8510981]                        ['رژگونه لالاتاپ شماره 03']
# 9932   [3288034]               ['ملاقه آشپزی دنور مدل D-LADLE 103']
# 9933  [10625014]          ['اجاق گاز رومیزی رینوزیت استار مدل RU3']
# 9934  [10940889]                 ['جامدادی پانی پو مدل پیشی عینکی']
# 9935   [9978127]           ['کارتن اسباب کشی مدل 001 بسته 10 عددی']
#
#                                                title_en            status  \
# 0     Samsung Galaxy A54 5G Dual SIM 256GB And 8GB R...        marketable
# ...
